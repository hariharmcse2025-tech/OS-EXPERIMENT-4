# %% [markdown]
# <a href="https://colab.research.google.com/github/hariharmcse2025-tech/OS-EXPERIMENT-4/blob/main/4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile fcfs.c
# #include<stdio.h>
#
# int main()
# {
#     int n,i;
#     int bt[20],wt[20],tat[20];
#     float avg_wt=0,avg_tat=0;
#
#     printf("Enter Number of Processes: ");
#     scanf("%d",&n);
#
#     for(i=0;i<n;i++)
#     {
#         printf("Enter Burst Time for P%d: ",i+1);
#         scanf("%d",&bt[i]);
#     }
#
#     wt[0]=0;
#
#     for(i=1;i<n;i++)
#         wt[i]=wt[i-1]+bt[i-1];
#
#     for(i=0;i<n;i++)
#     {
#         tat[i]=wt[i]+bt[i];
#         avg_wt+=wt[i];
#         avg_tat+=tat[i];
#     }
#
#     printf("\nProcess\tBT\tWT\tTAT\n");
#
#     for(i=0;i<n;i++)
#         printf("P%d\t%d\t%d\t%d\n",i+1,bt[i],wt[i],tat[i]);
#
#     printf("\nAverage Waiting Time = %.2f",avg_wt/n);
#     printf("\nAverage Turnaround Time = %.2f\n",avg_tat/n);
#
#     return 0;
# }
# Out:
# Writing fcfs.c

# %%
# !gcc fcfs.c -o fcfs

# %%
# !./fcfs
# Out:
# Enter Number of Processes: 3
# Enter Burst Time for P1: 1
# Enter Burst Time for P2: 2
# Enter Burst Time for P3: 3
#
# Process	BT	WT	TAT
# P1	1	0	1
# P2	2	1	3
# P3	3	3	6
#
# Average Waiting Time = 1.33
# Average Turnaround Time = 3.33

# %%
# %%writefile fcfs.sh
# #!/bin/bash
#
# echo "Enter Number of Processes"
# read n
#
# for ((i=0;i<n;i++))
# do
#     echo "Enter Burst Time for P$((i+1))"
#     read bt[$i]
# done
#
# wt[0]=0
#
# for ((i=1;i<n;i++))
# do
#     wt[$i]=$((wt[i-1]+bt[i-1]))
# done
#
# echo
# echo -e "Process\tBT\tWT\tTAT"
#
# total_wt=0
# total_tat=0
#
# for ((i=0;i<n;i++))
# do
#     tat[$i]=$((wt[i]+bt[i]))
#     total_wt=$((total_wt+wt[i]))
#     total_tat=$((total_tat+tat[i]))
#
#     echo -e "P$((i+1))\t${bt[i]}\t${wt[i]}\t${tat[i]}"
# done
#
# avg_wt=$(awk "BEGIN {printf \"%.2f\", $total_wt/$n}")
# avg_tat=$(awk "BEGIN {printf \"%.2f\", $total_tat/$n}")
#
# echo
# echo "Average Waiting Time = $avg_wt"
# echo "Average Turnaround Time = $avg_tat"
# Out:
# Writing fcfs.sh

# %%
# !chmod +x fcfs.sh
# !./fcfs.sh
# Out:
# Enter Number of Processes
# 3
# Enter Burst Time for P1
# 1
# Enter Burst Time for P2
# 2
# Enter Burst Time for P3
# 3
#
# Process	BT	WT	TAT
# P1	1	0	1
# P2	2	1	3
# P3	3	3	6
#
# Average Waiting Time = 1.33
# Average Turnaround Time = 3.33

# %%
# %%writefile sjf.c
# #include<stdio.h>
#
# int main()
# {
#     int n,i,j,temp;
#     int bt[20],wt[20],tat[20];
#     float avg_wt=0, avg_tat=0;
#
#     printf("Enter Number of Processes: ");
#     scanf("%d",&n);
#
#     for(i=0;i<n;i++)
#     {
#         printf("Enter Burst Time for P%d: ",i+1);
#         scanf("%d",&bt[i]);
#     }
#
#     // Sorting burst times in ascending order
#
#     for(i=0;i<n-1;i++)
#     {
#         for(j=i+1;j<n;j++)
#         {
#             if(bt[i] > bt[j])
#             {
#                 temp = bt[i];
#                 bt[i] = bt[j];
#                 bt[j] = temp;
#             }
#         }
#     }
#
#     wt[0] = 0;
#
#     for(i=1;i<n;i++)
#         wt[i] = wt[i-1] + bt[i-1];
#
#     printf("\nProcess\tBT\tWT\tTAT\n");
#
#     for(i=0;i<n;i++)
#     {
#         tat[i] = wt[i] + bt[i];
#
#         avg_wt += wt[i];
#         avg_tat += tat[i];
#
#         printf("P%d\t%d\t%d\t%d\n",
#                i+1,bt[i],wt[i],tat[i]);
#     }
#
#     avg_wt = avg_wt / n;
#     avg_tat = avg_tat / n;
#
#     printf("\nAverage Waiting Time = %.2f",avg_wt);
#     printf("\nAverage Turnaround Time = %.2f\n",avg_tat);
#
#     return 0;
# }
# Out:
# Writing sjf.c

# %%
# !gcc sjf.c -o sjf

# %%
# !./sjf
# Out:
# Enter Number of Processes: 3
# Enter Burst Time for P1: 7
# Enter Burst Time for P2: 8
# Enter Burst Time for P3: 9
#
# Process	BT	WT	TAT
# P1	7	0	7
# P2	8	7	15
# P3	9	15	24
#
# Average Waiting Time = 7.33
# Average Turnaround Time = 15.33

# %%
# %%writefile sjf.sh
# #!/bin/bash
#
# echo "Enter Number of Processes"
# read n
#
# for ((i=0;i<n;i++))
# do
#     echo "Enter Burst Time for P$((i+1))"
#     read bt[$i]
# done
#
# # Sorting burst times (Ascending Order)
#
# for ((i=0;i<n-1;i++))
# do
#     for ((j=i+1;j<n;j++))
#     do
#         if [ ${bt[i]} -gt ${bt[j]} ]
#         then
#             temp=${bt[i]}
#             bt[$i]=${bt[j]}
#             bt[$j]=$temp
#         fi
#     done
# done
#
# wt[0]=0
#
# echo
# echo -e "Process\tBT\tWT\tTAT"
#
# total_wt=0
# total_tat=0
#
# for ((i=0;i<n;i++))
# do
#     if [ $i -ne 0 ]
#     then
#         wt[$i]=$((wt[i-1]+bt[i-1]))
#     fi
#
#     tat[$i]=$((wt[i]+bt[i]))
#
#     total_wt=$((total_wt+wt[i]))
#     total_tat=$((total_tat+tat[i]))
#
#     echo -e "P$((i+1))\t${bt[i]}\t${wt[i]}\t${tat[i]}"
# done
#
# avg_wt=$(awk "BEGIN {printf \"%.2f\", $total_wt/$n}")
# avg_tat=$(awk "BEGIN {printf \"%.2f\", $total_tat/$n}")
#
# echo
# echo "Average Waiting Time = $avg_wt"
# echo "Average Turnaround Time = $avg_tat"
# Out:
# Writing sjf.sh

# %%
# !chmod +x sjf.sh
# !./sjf.sh
# Out:
# Enter Number of Processes
# 3
# Enter Burst Time for P1
# 1
# Enter Burst Time for P2
# 5
# Enter Burst Time for P3
# 7
#
# Process	BT	WT	TAT
# P1	1	0	1
# P2	5	1	6
# P3	7	6	13
#
# Average Waiting Time = 2.33
# Average Turnaround Time = 6.67

# %%
# %%writefile priority.c
# #include<stdio.h>
#
# int main()
# {
#     int n,i,j,temp;
#     int bt[20],pr[20],wt[20],tat[20];
#     float avg_wt=0, avg_tat=0;
#
#     printf("Enter Number of Processes: ");
#     scanf("%d",&n);
#
#     for(i=0;i<n;i++)
#     {
#         printf("\nEnter Burst Time for P%d: ",i+1);
#         scanf("%d",&bt[i]);
#
#         printf("Enter Priority for P%d: ",i+1);
#         scanf("%d",&pr[i]);
#     }
#
#     /* Sort according to priority */
#
#     for(i=0;i<n-1;i++)
#     {
#         for(j=i+1;j<n;j++)
#         {
#             if(pr[i] > pr[j])
#             {
#                 temp = pr[i];
#                 pr[i] = pr[j];
#                 pr[j] = temp;
#
#                 temp = bt[i];
#                 bt[i] = bt[j];
#                 bt[j] = temp;
#             }
#         }
#     }
#
#     wt[0] = 0;
#
#     for(i=1;i<n;i++)
#         wt[i] = wt[i-1] + bt[i-1];
#
#     printf("\nProcess\tPriority\tBT\tWT\tTAT\n");
#
#     for(i=0;i<n;i++)
#     {
#         tat[i] = wt[i] + bt[i];
#
#         avg_wt += wt[i];
#         avg_tat += tat[i];
#
#         printf("P%d\t%d\t\t%d\t%d\t%d\n",
#                i+1,pr[i],bt[i],wt[i],tat[i]);
#     }
#
#     avg_wt /= n;
#     avg_tat /= n;
#
#     printf("\nAverage Waiting Time = %.2f",avg_wt);
#     printf("\nAverage Turnaround Time = %.2f\n",avg_tat);
#
#     return 0;
# }
# Out:
# Writing priority.c

# %%
# !gcc priority.c -o priority

# %%
# !./priority
# Out:
# Enter Number of Processes: 3
#
# Enter Burst Time for P1: 4
# Enter Priority for P1: 5
#
# Enter Burst Time for P2: 5
# Enter Priority for P2: 6
#
# Enter Burst Time for P3: 1
# Enter Priority for P3: 2
#
# Process	Priority	BT	WT	TAT
# P1	2		1	0	1
# P2	5		4	1	5
# P3	6		5	5	10
#
# Average Waiting Time = 2.00
# Average Turnaround Time = 5.33

# %%
# %%writefile priority.sh
# #!/bin/bash
#
# echo "Enter Number of Processes"
# read n
#
# for ((i=0;i<n;i++))
# do
#     echo "Enter Burst Time for P$((i+1))"
#     read bt[$i]
#
#     echo "Enter Priority for P$((i+1))"
#     read pr[$i]
# done
#
# # Sort according to Priority
#
# for ((i=0;i<n-1;i++))
# do
#     for ((j=i+1;j<n;j++))
#     do
#         if [ ${pr[i]} -gt ${pr[j]} ]
#         then
#             temp=${pr[i]}
#             pr[$i]=${pr[j]}
#             pr[$j]=$temp
#
#             temp=${bt[i]}
#             bt[$i]=${bt[j]}
#             bt[$j]=$temp
#         fi
#     done
# done
#
# wt[0]=0
#
# echo
# echo -e "Process\tPriority\tBT\tWT\tTAT"
#
# total_wt=0
# total_tat=0
#
# for ((i=0;i<n;i++))
# do
#     if [ $i -ne 0 ]
#     then
#         wt[$i]=$((wt[i-1]+bt[i-1]))
#     fi
#
#     tat[$i]=$((wt[i]+bt[i]))
#
#     total_wt=$((total_wt+wt[i]))
#     total_tat=$((total_tat+tat[i]))
#
#     echo -e "P$((i+1))\t${pr[i]}\t\t${bt[i]}\t${wt[i]}\t${tat[i]}"
# done
#
# avg_wt=$(awk "BEGIN {printf \"%.2f\", $total_wt/$n}")
# avg_tat=$(awk "BEGIN {printf \"%.2f\", $total_tat/$n}")
#
# echo
# echo "Average Waiting Time = $avg_wt"
# echo "Average Turnaround Time = $avg_tat"
# Out:
# Writing priority.sh

# %%
# !chmod +x priority.sh
# !./priority.sh
# Out:
# Enter Number of Processes
# 3
# Enter Burst Time for P1
# 4
# Enter Priority for P1
# 5
# Enter Burst Time for P2
# 6
# Enter Priority for P2
# 4
# Enter Burst Time for P3
# 1
# Enter Priority for P3
# 2
#
# Process	Priority	BT	WT	TAT
# P1	2		1	0	1
# P2	4		6	1	7
# P3	5		4	7	11
#
# Average Waiting Time = 2.67
# Average Turnaround Time = 6.33

# %%
# %%writefile rr.c
# #include<stdio.h>
#
# int main()
# {
#     int n, tq, i;
#     int bt[20], rem_bt[20];
#     int wt[20] = {0}, tat[20];
#     int time = 0, done;
#     float avg_wt = 0, avg_tat = 0;
#
#     printf("Enter Number of Processes: ");
#     scanf("%d", &n);
#
#     for(i = 0; i < n; i++)
#     {
#         printf("Enter Burst Time for P%d: ", i + 1);
#         scanf("%d", &bt[i]);
#
#         rem_bt[i] = bt[i];
#     }
#
#     printf("Enter Time Quantum: ");
#     scanf("%d", &tq);
#
#     do
#     {
#         done = 1;
#
#         for(i = 0; i < n; i++)
#         {
#             if(rem_bt[i] > 0)
#             {
#                 done = 0;
#
#                 if(rem_bt[i] > tq)
#                 {
#                     time += tq;
#                     rem_bt[i] -= tq;
#                 }
#                 else
#                 {
#                     time += rem_bt[i];
#                     wt[i] = time - bt[i];
#                     rem_bt[i] = 0;
#                 }
#             }
#         }
#
#     } while(!done);
#
#     printf("\nProcess\tBT\tWT\tTAT\n");
#
#     for(i = 0; i < n; i++)
#     {
#         tat[i] = bt[i] + wt[i];
#
#         avg_wt += wt[i];
#         avg_tat += tat[i];
#
#         printf("P%d\t%d\t%d\t%d\n",
#                i + 1,bt[i],wt[i],tat[i]);
#     }
#
#     avg_wt /= n;
#     avg_tat /= n;
#
#     printf("\nAverage Waiting Time = %.2f",avg_wt);
#     printf("\nAverage Turnaround Time = %.2f\n",avg_tat);
#
#     return 0;
# }
# Out:
# Writing rr.c

# %%
# !gcc rr.c -o rr

# %%
# !./rr
# Out:
# Enter Number of Processes: 3
# Enter Burst Time for P1: 2
# Enter Burst Time for P2: 1
# Enter Burst Time for P3: 4
# Enter Time Quantum: 5
#
# Process	BT	WT	TAT
# P1	2	0	2
# P2	1	2	3
# P3	4	3	7
#
# Average Waiting Time = 1.67
# Average Turnaround Time = 4.00

# %%
# %%writefile rr.sh
# #!/bin/bash
#
# echo "Enter Number of Processes"
# read n
#
# for ((i=0;i<n;i++))
# do
#     echo "Enter Burst Time for P$((i+1))"
#     read bt[$i]
#     rem_bt[$i]=${bt[$i]}
# done
#
# echo "Enter Time Quantum"
# read tq
#
# time=0
#
# while true
# do
#     done=1
#
#     for ((i=0;i<n;i++))
#     do
#         if [ ${rem_bt[i]} -gt 0 ]
#         then
#             done=0
#
#             if [ ${rem_bt[i]} -gt $tq ]
#             then
#                 time=$((time+tq))
#                 rem_bt[$i]=$((rem_bt[i]-tq))
#             else
#                 time=$((time+rem_bt[i]))
#                 wt[$i]=$((time-bt[i]))
#                 rem_bt[$i]=0
#             fi
#         fi
#     done
#
#     [ $done -eq 1 ] && break
# done
#
# echo
# echo -e "Process\tBT\tWT\tTAT"
#
# total_wt=0
# total_tat=0
#
# for ((i=0;i<n;i++))
# do
#     tat[$i]=$((bt[i]+wt[i]))
#
#     total_wt=$((total_wt+wt[i]))
#     total_tat=$((total_tat+tat[i]))
#
#     echo -e "P$((i+1))\t${bt[i]}\t${wt[i]}\t${tat[i]}"
# done
#
# avg_wt=$(awk "BEGIN {printf \"%.2f\", $total_wt/$n}")
# avg_tat=$(awk "BEGIN {printf \"%.2f\", $total_tat/$n}")
#
# echo
# echo "Average Waiting Time = $avg_wt"
# echo "Average Turnaround Time = $avg_tat"
# Out:
# Writing rr.sh

# %%
# !chmod +x rr.sh
# !./rr.sh
# Out:
# Enter Number of Processes
# 3
# Enter Burst Time for P1
# 1
# Enter Burst Time for P2
# 1
# Enter Burst Time for P3
# 2
# Enter Time Quantum
# 2
#
# Process	BT	WT	TAT
# P1	1	0	1
# P2	1	1	2
# P3	2	2	4
#
# Average Waiting Time = 1.00
# Average Turnaround Time = 2.33
